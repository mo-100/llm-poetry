# %%
import pandas as pd

df = pd.read_csv("hf://datasets/faisalq/poemsDataset/poemsDataset.csv")
df
# Out:
#                                 poem_title           first_hemistich  \
# 0         إيهاً جُدابُ سَيِّدَ الْأَعْرابِ     إيها جداب سيد الأعراب
# 1         إيهاً جُدابُ سَيِّدَ الْأَعْرابِ   يا طيب الأحساب والأنساب
# 2         إيهاً جُدابُ سَيِّدَ الْأَعْرابِ    بالعزم والحزم وبالعذاب
# 3         إيهاً جُدابُ سَيِّدَ الْأَعْرابِ   قد حل ديني واقتضى حسابي
# 4        إِنَّ الْجُنُودَ حَثُّها طِلابُها     إن الجنود حثها طلابها
# ...                                    ...                       ...
# 2090902              ألا إلا تكن إبل فمعزى      تروح كأنها مما أصابت
# 2090903              أرانا موضعين لأمر غيب    وكل مكارم الأخلاق صارت
# 2090904           ألا أبلغ بني العجلان عني  بأنا قد قتلنا الخير قرطا
# 2090905              بكى فرثت له أجبال صبح   إذا اكتنفا بضرهما سقيما
# 2090906            الا من مبلغ الاحلاف عني    ابت لي عفتي وأبى بلائي
#
#                   second_hemistich                                    poet  \
# 0           يا معدن الطعان والضراب  صَفِيَّة بنت ثَعْلَبَة الشَّيْبانِيَّة
# 1             قم لي مقام سيدي شهاب  صَفِيَّة بنت ثَعْلَبَة الشَّيْبانِيَّة
# 2         شمر وقم يا ويك في النقاب  صَفِيَّة بنت ثَعْلَبَة الشَّيْبانِيَّة
# 3                              NaN  صَفِيَّة بنت ثَعْلَبَة الشَّيْبانِيَّة
# 4            والأرقميون فذا شهابها  صَفِيَّة بنت ثَعْلَبَة الشَّيْبانِيَّة
# ...                            ...                                     ...
# 2090902        معلقة بأحقيها الدلي                              امرؤ القيس
# 2090903      إليه همتي وبه اكتسابي                              امرؤ القيس
# 2090904     وجلنا في سراة بني نمير                      ابن العجلان النهدي
# 2090905    يعادى الداء ليس له مقيت                      ابن العجلان النهدي
# 2090906  وأخذي الحمد بالثمن الربيح                            ابن الأطنابة
#
#          meter sub_meter البحر جزء البحر        era rhyme قافية  type_en  \
# 0        rajaz    majzuu   رجز     مجزوء  Pre_Islam   baa     ب      NaN
# 1        rajaz    majzuu   رجز     مجزوء  Pre_Islam   baa     ب      NaN
# 2        rajaz    majzuu   رجز     مجزوء  Pre_Islam   baa     ب      NaN
# 3        rajaz    majzuu   رجز     مجزوء  Pre_Islam   baa     ب      NaN
# 4        rajaz    majzuu   رجز     مجزوء  Pre_Islam   baa     ب      NaN
# ...        ...       ...   ...       ...        ...   ...   ...      ...
# 2090902  wafer  complete  وافر       تام  Pre_Islam   yaa     ي  general
# 2090903  wafer  complete  وافر       تام  Pre_Islam   baa     ب  general
# 2090904  wafer  complete  وافر       تام  Pre_Islam   raa     ر  general
# 2090905  wafer  complete  وافر       تام  Pre_Islam   taa     ت  general
# 2090906  wafer  complete  وافر       تام  Pre_Islam  hhaa     ح  general
#
#             type_ar                                               link gender
# 0               NaN  https://poetry.dctabudhabi.ae/#/poems/261793-%...      f
# 1               NaN  https://poetry.dctabudhabi.ae/#/poems/261793-%...      f
# 2               NaN  https://poetry.dctabudhabi.ae/#/poems/261793-%...      f
# 3               NaN  https://poetry.dctabudhabi.ae/#/poems/261793-%...      f
# 4               NaN  https://poetry.dctabudhabi.ae/#/poems/261792-%...      f
# ...             ...                                                ...    ...
# 2090902  قصائد عامه                https://www.aldiwan.net/poem71.html      m
# 2090903  قصائد عامه                https://www.aldiwan.net/poem60.html      m
# 2090904  قصائد عامه                https://www.aldiwan.net/poem40.html      m
# 2090905  قصائد عامه                https://www.aldiwan.net/poem34.html      m
# 2090906  قصائد عامه                https://www.aldiwan.net/poem22.html      m
#
# [2090907 rows x 15 columns]

# %%
df[df['poem_title'] == 'عَفـا جـانِبُ الْبَطْحاءِ مِنْ إِبْنِ هاشِمٍ']
# Out:
#                                       poem_title  \
# 25  عَفـا جـانِبُ الْبَطْحاءِ مِنْ إِبْنِ هاشِمٍ
# 26  عَفـا جـانِبُ الْبَطْحاءِ مِنْ إِبْنِ هاشِمٍ
# 27  عَفـا جـانِبُ الْبَطْحاءِ مِنْ إِبْنِ هاشِمٍ
# 28  عَفـا جـانِبُ الْبَطْحاءِ مِنْ إِبْنِ هاشِمٍ
#
#                  first_hemistich                second_hemistich  \
# 25  عفا جانب البطحاء من إبن هاشم     وجاور لحدا خارجا في الغماغم
# 26     دعته المنايا دعوة فأجابها  وما تركت في الناس مثل ابن هاشم
# 27       عشية راحوا يحملون سريره        تعاوره أصحابه في التزاحم
# 28   فإن يك غالته المنايا وريبها      فقد كان معطاء كثير التراحم
#
#                     poet   meter sub_meter البحر جزء البحر        era rhyme  \
# 25  آمِنَةُ بِنْتُ وَهَب  taweel  complete  طويل       تام  Pre_Islam  meem
# 26  آمِنَةُ بِنْتُ وَهَب  taweel  complete  طويل       تام  Pre_Islam  meem
# 27  آمِنَةُ بِنْتُ وَهَب  taweel  complete  طويل       تام  Pre_Islam  meem
# 28  آمِنَةُ بِنْتُ وَهَب  taweel  complete  طويل       تام  Pre_Islam  meem
#
#    قافية  type_en     type_ar  \
# 25     م      NaN         NaN
# 26     م      NaN         NaN
# 27     م  general  قصائد عامه
# 28     م  general  قصائد عامه
#
#                                                  link gender
# 25  https://poetry.dctabudhabi.ae/#/poems/97691-%D...      f
# 26  https://poetry.dctabudhabi.ae/#/poems/97691-%D...      f
# 27  https://poetry.dctabudhabi.ae/#/poems/97691-%D...      f
# 28  https://poetry.dctabudhabi.ae/#/poems/97691-%D...      f

# %%
df[df['second_hemistich'].isna()]
# Out:
#                                     poem_title             first_hemistich  \
# 3             إيهاً جُدابُ سَيِّدَ الْأَعْرابِ     قد حل ديني واقتضى حسابي
# 46       أَشْبِهْ أَخِي أَوْ أَشْبِهَنْ أَباكا         تقصر عن مناله يداكا
# 161           وَصَاحِبٍ نَادَيْتُهُ فغَمْغَمَا         وصاحب ناديته فغمغما
# 162           وَصَاحِبٍ نَادَيْتُهُ فغَمْغَمَا         يريد لبيك وما تكلما
# 163           وَصَاحِبٍ نَادَيْتُهُ فغَمْغَمَا  قد صار من خوف الكلام أعجما
# ...                                        ...                         ...
# 2088167             سددت الأذن عن داعي التصابي  سددت الأذن عن داعي التصابي
# 2089093                  إلي بكأسك الأشهى إليا      وغافلت الرقيب وقلت هيا
# 2089653              أعزي القوم لو سمعوا عزائي       فكل العالمين إلى فناء
# 2089656              أعزي القوم لو سمعوا عزائي       بنظرة واجد قلق الرجاء
# 2089659              أعزي القوم لو سمعوا عزائي    ولا قوما كقومك في الدهاء
#
#         second_hemistich البحر قافية  \
# 3                    NaN   رجز     ب
# 46                   NaN   رجز     ك
# 161                  NaN   رجز     م
# 162                  NaN   رجز     م
# 163                  NaN   رجز     م
# ...                  ...   ...   ...
# 2088167              NaN  وافر     ي
# 2089093              NaN  وافر   NaN
# 2089653              NaN  وافر   NaN
# 2089656              NaN  وافر   NaN
# 2089659              NaN  وافر   NaN
#
#                                                       link
# 3        https://poetry.dctabudhabi.ae/#/poems/261793-%...
# 46       https://poetry.dctabudhabi.ae/#/poems/261788-%...
# 161      https://poetry.dctabudhabi.ae/#/poems/261737-%...
# 162      https://poetry.dctabudhabi.ae/#/poems/261737-%...
# 163      https://poetry.dctabudhabi.ae/#/poems/261737-%...
# ...                                                    ...
# 2088167             https://www.aldiwan.net/poem37472.html
# 2089093             https://www.aldiwan.net/poem20620.html
# 2089653             https://www.aldiwan.net/poem10497.html
# 2089656             https://www.aldiwan.net/poem10497.html
# 2089659             https://www.aldiwan.net/poem10497.html
#
# [89498 rows x 6 columns]

# %%
df[df['poem_title'] == 'إيهاً جُدابُ سَيِّدَ الْأَعْرابِ']
# Out:
#                          poem_title          first_hemistich  \
# 0  إيهاً جُدابُ سَيِّدَ الْأَعْرابِ    إيها جداب سيد الأعراب
# 1  إيهاً جُدابُ سَيِّدَ الْأَعْرابِ  يا طيب الأحساب والأنساب
# 2  إيهاً جُدابُ سَيِّدَ الْأَعْرابِ   بالعزم والحزم وبالعذاب
# 3  إيهاً جُدابُ سَيِّدَ الْأَعْرابِ  قد حل ديني واقتضى حسابي
#
#            second_hemistich البحر قافية  \
# 0    يا معدن الطعان والضراب   رجز     ب
# 1      قم لي مقام سيدي شهاب   رجز     ب
# 2  شمر وقم يا ويك في النقاب   رجز     ب
# 3                       NaN   رجز     ب
#
#                                                 link
# 0  https://poetry.dctabudhabi.ae/#/poems/261793-%...
# 1  https://poetry.dctabudhabi.ae/#/poems/261793-%...
# 2  https://poetry.dctabudhabi.ae/#/poems/261793-%...
# 3  https://poetry.dctabudhabi.ae/#/poems/261793-%...

# %%
df = df[['poem_title', 'first_hemistich', 'second_hemistich', 'البحر', 'قافية', 'link']]
df
# Out:
#                                 poem_title           first_hemistich  \
# 0         إيهاً جُدابُ سَيِّدَ الْأَعْرابِ     إيها جداب سيد الأعراب
# 1         إيهاً جُدابُ سَيِّدَ الْأَعْرابِ   يا طيب الأحساب والأنساب
# 2         إيهاً جُدابُ سَيِّدَ الْأَعْرابِ    بالعزم والحزم وبالعذاب
# 3         إيهاً جُدابُ سَيِّدَ الْأَعْرابِ   قد حل ديني واقتضى حسابي
# 4        إِنَّ الْجُنُودَ حَثُّها طِلابُها     إن الجنود حثها طلابها
# ...                                    ...                       ...
# 2090902              ألا إلا تكن إبل فمعزى      تروح كأنها مما أصابت
# 2090903              أرانا موضعين لأمر غيب    وكل مكارم الأخلاق صارت
# 2090904           ألا أبلغ بني العجلان عني  بأنا قد قتلنا الخير قرطا
# 2090905              بكى فرثت له أجبال صبح   إذا اكتنفا بضرهما سقيما
# 2090906            الا من مبلغ الاحلاف عني    ابت لي عفتي وأبى بلائي
#
#                   second_hemistich البحر قافية  \
# 0           يا معدن الطعان والضراب   رجز     ب
# 1             قم لي مقام سيدي شهاب   رجز     ب
# 2         شمر وقم يا ويك في النقاب   رجز     ب
# 3                              NaN   رجز     ب
# 4            والأرقميون فذا شهابها   رجز     ب
# ...                            ...   ...   ...
# 2090902        معلقة بأحقيها الدلي  وافر     ي
# 2090903      إليه همتي وبه اكتسابي  وافر     ب
# 2090904     وجلنا في سراة بني نمير  وافر     ر
# 2090905    يعادى الداء ليس له مقيت  وافر     ت
# 2090906  وأخذي الحمد بالثمن الربيح  وافر     ح
#
#                                                       link
# 0        https://poetry.dctabudhabi.ae/#/poems/261793-%...
# 1        https://poetry.dctabudhabi.ae/#/poems/261793-%...
# 2        https://poetry.dctabudhabi.ae/#/poems/261793-%...
# 3        https://poetry.dctabudhabi.ae/#/poems/261793-%...
# 4        https://poetry.dctabudhabi.ae/#/poems/261792-%...
# ...                                                    ...
# 2090902                https://www.aldiwan.net/poem71.html
# 2090903                https://www.aldiwan.net/poem60.html
# 2090904                https://www.aldiwan.net/poem40.html
# 2090905                https://www.aldiwan.net/poem34.html
# 2090906                https://www.aldiwan.net/poem22.html
#
# [2090907 rows x 6 columns]

# %%
SHATR_TOKEN = '<|SHATR|>'
BEET_TOKEN = '<|BEET|>'

# %%
print(df.shape)
df = df[df['البحر'] == 'طويل']
print(df.shape)
# Out:
# (2090907, 6)
# (442763, 6)

# %%
df.isnull().sum()
# Out:
# poem_title            258
# first_hemistich         0
# second_hemistich     7834
# البحر                   0
# قافية               30202
# link                    0
# dtype: int64

# %%
from collections import defaultdict


# Function to format dataset for training
def format_poetry(df):
    # Group verses by poem title
    verses_dict = defaultdict(list)
    meter_dict = {}
    rhyme_dict = {}
    link_dict = {}
    for poem_title, meter, rhyme, shatr1, shatr2, link in zip(
        df["poem_title"], df['البحر'], df['قافية'], df['first_hemistich'], df['second_hemistich'], df['link']
    ):
        if meter is not None:
            meter_dict[poem_title] = meter
        if rhyme is not None:
            rhyme_dict[poem_title] = rhyme
        link_dict[poem_title] = link
        if shatr2 is None or type(shatr2) == float:
            verse = shatr1 + SHATR_TOKEN
        else:
            verse = shatr1 + SHATR_TOKEN + shatr2 + SHATR_TOKEN

        verses_dict[poem_title].append(verse)

    body_dict = {}
    for t, verses in verses_dict.items():
        body_dict[t] = BEET_TOKEN.join(verses) + BEET_TOKEN

    # Format the full poem in the required structure
    def get_poem(title):
        return {
            'title': title,
            'body': body_dict[title],
            'meter': meter_dict[title],
            'rhyme': rhyme_dict[title],
            'link': link_dict[title],
        }
    formatted_texts = [get_poem(t) for t in body_dict.keys()]
    return formatted_texts

df_grouped = format_poetry(df)

# %%
nas = 0
clean_dataset = []

def is_na(item):
    kws = ['title', 'body', 'meter', 'rhyme', 'link']
    for k in kws:
        if item[k] is None or type(item[k]) == float or item[k].strip() == '':
            return True
    return False

for v in df_grouped:
    if is_na(v):
        nas += 1
    else:
        clean_dataset.append(v)
nas
# Out:
# 1086

# %%
len(clean_dataset)
# Out:
# 35556

# %%
import random

random.Random(42).shuffle(clean_dataset)

# %%
clean_dataset[0]
# Out:
# {'title': 'بشائر نعمى لا يقوم لها شكر',
#  'body': 'بشائر نعمى لا يقوم لها شكر<|SHATR|>وتجديد فخر لا يقابله فخر<|SHATR|><|BEET|>وصارم ملك قلدوا فيه صارما<|SHATR|>متى ما سما للفتح جوده النصر<|SHATR|><|BEET|>تسربل داود الوزير مطارفا<|SHATR|>وما هي إلا الحكم والنهي والأمر<|SHATR|><|BEET|>مطارف حاقانية النسج لوتها<|SHATR|>له الأبيض الفتاك لا البيض والصفر<|SHATR|><|BEET|>اذا قابلتها الشمس صدت كأنها<|SHATR|>فتاة رأت ضراء أعوزها الخدر<|SHATR|><|BEET|>متى اشرقت في مكبيه إستفزها<|SHATR|>لهيبته واعتدها الخوف والذعر<|SHATR|><|BEET|>مناكب لا تهتز إلا لسؤدد<|SHATR|>وكم منكب بالؤم قد هزه الغدر<|SHATR|><|BEET|>اذا نشرت يوما مساعيه للعلى<|SHATR|>بدا نشرها والعود زينه النشر<|SHATR|><|BEET|>اياد إذا مافاض زاخر نيلها<|SHATR|>لذي عثرة يستصغر الغيث والبحر<|SHATR|><|BEET|>تدر شطور العفو عن ذي جريرة<|SHATR|>وللظلم ضرع لا يدر له شطر<|SHATR|><|BEET|>وأوسع عدلا مستفيضا على الورى<|SHATR|>وما ضل في يوم الهياج له صدر<|SHATR|><|BEET|>بحزم اذا ما قارع الدهر غربه<|SHATR|>مضى حده وانقاد طوعا له الدهر<|SHATR|><|BEET|>وليس ينكران تعذر وصفه<|SHATR|>ومن كاده عد النجوم له العذر<|SHATR|><|BEET|>فلا يطمعن في نعته ذو فصاحة<|SHATR|>واين من الأرض المجرة والنسر<|SHATR|><|BEET|>كسى العز أفاق العراق فأرضه<|SHATR|>جوانبها من سحب نائله خضر<|SHATR|><|BEET|>وكيف نعد البيض بيضا وفي الوغى<|SHATR|>مواضيه قد عادت وألوانها حمر<|SHATR|><|BEET|>مددت أكفي بالدعاء مؤرخا<|SHATR|>ملابس سعد طيها رفرف النصر<|SHATR|><|BEET|>',
#  'meter': 'طويل',
#  'rhyme': 'ر',
#  'link': 'https://poetry.dctabudhabi.ae/#/poems/129384-%D8%A8%D8%B4%D8%A7%D8%A6%D8%B1-%D9%86%D8%B9%D9%85%D9%89-%D9%84%D8%A7-%D9%8A%D9%82%D9%88%D9%85-%D9%84%D9%87%D8%A7-%D8%B4%D9%83%D8%B1'}

# %%
clean_dataset[0]['body'].count('<|BEET|>')
# Out:
# 17

# %%
import json

with open('filtered_clean.jsonl', 'w') as f:
    for item in clean_dataset:
        json.dump(item, f)
        f.write('\n')
